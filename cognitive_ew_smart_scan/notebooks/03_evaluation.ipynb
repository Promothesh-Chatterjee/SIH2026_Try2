# %% [markdown]
# # 03. Final Evaluation & Figures of Merit
#
# This notebook covers the final performance evaluation of our SmartScan system across testing pulse trains. Tracking V-measure, AMI, Pd, Pfa, and latency.
